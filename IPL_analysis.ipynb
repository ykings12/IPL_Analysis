# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# type(data)-->  to check that table is data frame for pandas

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
# Out:
# (636, 18)

# %%
data.shape[0]
# Out:
# 636

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
data[['team1','team2','winner']].shape
# Out:
# (636, 3)

# %%
data.iloc[[1,34,2]]
# Out:
#     id  season        city        date             team1  \
# 1    2    2017        Pune  2017-04-06    Mumbai Indians
# 34  35    2017  Chandigarh  2017-04-30  Delhi Daredevils
# 2    3    2017      Rajkot  2017-04-07     Gujarat Lions
#
#                      team2             toss_winner toss_decision  result  \
# 1   Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 34         Kings XI Punjab         Kings XI Punjab         field  normal
# 2    Kolkata Knight Riders   Kolkata Knight Riders         field  normal
#
#     dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1            0  Rising Pune Supergiant            0               7
# 34           0         Kings XI Punjab            0              10
# 2            0   Kolkata Knight Riders            0              10
#
#    player_of_match                                              venue  \
# 1        SPD Smith            Maharashtra Cricket Association Stadium
# ...

# %%
 data.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data.iloc[1:10, 0:4]
# Out:
#    id  season       city        date
# 1   2    2017       Pune  2017-04-06
# 2   3    2017     Rajkot  2017-04-07
# 3   4    2017     Indore  2017-04-08
# 4   5    2017  Bangalore  2017-04-08
# 5   6    2017  Hyderabad  2017-04-09
# 6   7    2017     Mumbai  2017-04-09
# 7   8    2017     Indore  2017-04-10
# 8   9    2017       Pune  2017-04-11
# 9  10    2017     Mumbai  2017-04-12

# %%
mask=(data['player_of_match']=='V Kohli')
data[mask]
# Out:
#       id  season       city        date                        team1  \
# 262  263    2011      Delhi  2011-04-26             Delhi Daredevils
# 267  268    2011  Bangalore  2011-04-29  Royal Challengers Bangalore
# 400  401    2013  Bangalore  2013-04-16             Delhi Daredevils
# 431  432    2013  Bangalore  2013-04-09          Sunrisers Hyderabad
# 451  452    2013  Bangalore  2013-05-18  Royal Challengers Bangalore
# 567  568    2015  Hyderabad  2015-05-15          Sunrisers Hyderabad
# 594  595    2016     Rajkot  2016-04-24  Royal Challengers Bangalore
# 610  611    2016  Bangalore  2016-05-07      Rising Pune Supergiants
# 623  624    2016    Kolkata  2016-05-16        Kolkata Knight Riders
# 625  626    2016  Bangalore  2016-05-18  Royal Challengers Bangalore
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data[mask].shape
# Out:
# (11, 18)

# %%
def get_MOM_count(MOM):
    Mask=data['player_of_match']==MOM
    return data[Mask].shape[0]

# %%
get_MOM_count('Rashid Khan')
# Out:
# 2

# %%
def get_matches_won_count(Team):
    Mask=data['winner']==Team
    return data[Mask].shape[0]

# %%
get_matches_won_count('Mumbai Indians')
# Out:
# 92

# %%
mask1=data['season']>2014
mask2=data['city']=='Hyderabad'
data[mask2 & mask1].shape[0]
# Out:
# 19

# %%
data=pd.read_csv('matches.csv')
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
mask1=data['season']==2016
mask2=data['city']=='Bangalore'
mask3=data['winner']=='Royal Challengers Bangalore'

data[mask1 & mask2 & mask3]
# Out:
#       id  season       city        date                        team1  \
# 579  580    2016  Bangalore  2016-04-12  Royal Challengers Bangalore
# 610  611    2016  Bangalore  2016-05-07      Rising Pune Supergiants
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 625  626    2016  Bangalore  2016-05-18  Royal Challengers Bangalore
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# 579          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 610  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 619                Gujarat Lions                Gujarat Lions         field
# 625              Kings XI Punjab              Kings XI Punjab         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %%
def get_season_winner_city(season,team,city):
    mask1=data['season']==season
    mask2=data['city']==city
    mask3=data['winner']==team

    return data[mask1 & mask2 & mask3]

# %%
get_season_winner_city(2010, 'Mumbai Indians', 'Mumbai')
# Out:
#       id  season    city        date                  team1  \
# 175  176    2010  Mumbai  2010-03-13         Mumbai Indians
# 190  191    2010  Mumbai  2010-03-22  Kolkata Knight Riders
# 193  194    2010  Mumbai  2010-03-25    Chennai Super Kings
# 198  199    2010  Mumbai  2010-03-28         Mumbai Indians
# 200  201    2010  Mumbai  2010-03-30        Kings XI Punjab
# 206  207    2010  Mumbai  2010-04-03         Mumbai Indians
# 220  221    2010  Mumbai  2010-04-13         Mumbai Indians
# 230  231    2010  Mumbai  2010-04-21         Mumbai Indians
#
#                            team2            toss_winner toss_decision  result  \
# 175             Rajasthan Royals         Mumbai Indians           bat  normal
# 190               Mumbai Indians  Kolkata Knight Riders           bat  normal
# 193               Mumbai Indians         Mumbai Indians         field  normal
# 198              Deccan Chargers        Deccan Chargers         field  normal
# ...

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
data['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %% [markdown]
# **Plot fucntion

# %%
 import matplotlib.pyplot as plt

# %%
data['winner'].value_counts().head(12).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['win_by_runs'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
my_series=data['winner'].value_counts()

# %%
my_series['Chennai Super Kings']
# Out:
# 79

# %%
abc=((data['winner'].value_counts())/(data['team1'].value_counts()+data['team2'].value_counts()))

# %%
A=abc.sort_values(0,ascending=False).plot(kind='bar')
A
# Out:
# C:\Users\yashs\AppData\Local\Temp\ipykernel_24308\3143839512.py:1: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   A=abc.sort_values(0,ascending=False).plot(kind='bar')
# <AxesSubplot:>

# %%
highest_matches=data['team1'].value_counts()+data['team2'].value_counts()
highest_matches.sort_values(ascending=False).head()
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# dtype: int64

# %%
data.sort_values('city',ascending=False)
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.shape[0]
# Out:
# 636

# %%
data.sort_values(['city','date'])
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %%
data.sort_values(['city','date'],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
mask=data['player_of_match']=='SK Raina'
data[mask].sort_values('date')
# Out:
#       id  season       city        date                        team1  \
# 113  114    2008  Hyderabad  2008-05-27              Deccan Chargers
# 136  137    2009  Centurion  2009-04-30          Chennai Super Kings
# 210  211    2010    Chennai  2010-04-06          Chennai Super Kings
# 233  234    2010     Mumbai  2010-04-25          Chennai Super Kings
# 303  304    2011     Mumbai  2011-05-24  Royal Challengers Bangalore
# 351  352    2012    Chennai  2012-05-04          Chennai Super Kings
# 424  425    2013    Chennai  2013-05-02          Chennai Super Kings
# 434  435    2013  Hyderabad  2013-05-08          Chennai Super Kings
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 514  515    2014     Mumbai  2014-05-28               Mumbai Indians
# 537  538    2015  Bangalore  2015-04-22          Chennai Super Kings
# 553  554    2015    Chennai  2015-05-04          Chennai Super Kings
# 629  630    2016     Kanpur  2016-05-21               Mumbai Indians
# ...

# %%
data.drop_duplicates(subset=['city','season']).sort_values('city')
# Out:
#       id  season           city        date                        team1  \
# 457  458    2014      Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 481  482    2014      Ahmedabad  2014-05-05             Rajasthan Royals
# 179  180    2010      Ahmedabad  2010-03-15             Rajasthan Royals
# 525  526    2015      Ahmedabad  2015-04-14               Mumbai Indians
# 382  383    2013      Bangalore  2013-04-04  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 458  459    2014        Sharjah  2014-04-17             Delhi Daredevils
# 528  529    2015  Visakhapatnam  2015-04-16          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 461  462    2014            NaN  2014-04-19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.shape
# Out:
# (636, 18)

# %%
data.drop_duplicates(subset=['season'],keep='last').sort_values('season')
# Out:
#       id  season          city        date                team1  \
# 116  117    2008        Mumbai  2008-06-01  Chennai Super Kings
# 173  174    2009  Johannesburg  2009-05-24      Deccan Chargers
# 233  234    2010        Mumbai  2010-04-25  Chennai Super Kings
# 306  307    2011       Chennai  2011-05-28  Chennai Super Kings
# 380  381    2012       Chennai  2012-05-27  Chennai Super Kings
# 456  457    2013       Kolkata  2013-05-26       Mumbai Indians
# 516  517    2014     Bangalore  2014-06-01      Kings XI Punjab
# 575  576    2015       Kolkata  2015-05-24       Mumbai Indians
# 635  636    2016     Bangalore  2016-05-29  Sunrisers Hyderabad
# 58    59    2017     Hyderabad  2017-05-21       Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 116             Rajasthan Royals             Rajasthan Royals         field
# 173  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
season=data.groupby('season')

# %%
season

# %%
len(season)
# Out:
# 10

# %%
season.size()
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# dtype: int64

# %%
season.first()
# Out:
#          id       city        date                  team1  \
# season
# 2008     60  Bangalore  2008-04-18  Kolkata Knight Riders
# 2009    118  Cape Town  2009-04-18         Mumbai Indians
# 2010    175     Mumbai  2010-03-12  Kolkata Knight Riders
# 2011    235    Chennai  2011-04-08    Chennai Super Kings
# 2012    308    Chennai  2012-04-04    Chennai Super Kings
# 2013    382    Kolkata  2013-04-03       Delhi Daredevils
# 2014    458  Abu Dhabi  2014-04-16  Kolkata Knight Riders
# 2015    518    Kolkata  2015-04-08         Mumbai Indians
# 2016    577     Mumbai  2016-04-09         Mumbai Indians
# 2017      1  Hyderabad  2017-04-05    Sunrisers Hyderabad
#
#                               team2                  toss_winner  \
# season
# 2008    Royal Challengers Bangalore  Royal Challengers Bangalore
# 2009            Chennai Super Kings          Chennai Super Kings
# 2010                Deccan Chargers              Deccan Chargers
# ...

# %%
season.last()
# Out:
#          id          city        date                team1  \
# season
# 2008    117        Mumbai  2008-06-01  Chennai Super Kings
# 2009    174  Johannesburg  2009-05-24      Deccan Chargers
# 2010    234        Mumbai  2010-04-25  Chennai Super Kings
# 2011    307       Chennai  2011-05-28  Chennai Super Kings
# 2012    381       Chennai  2012-05-27  Chennai Super Kings
# 2013    457       Kolkata  2013-05-26       Mumbai Indians
# 2014    517     Bangalore  2014-06-01      Kings XI Punjab
# 2015    576       Kolkata  2015-05-24       Mumbai Indians
# 2016    636     Bangalore  2016-05-29  Sunrisers Hyderabad
# 2017     59     Hyderabad  2017-05-21       Mumbai Indians
#
#                               team2                  toss_winner  \
# season
# 2008               Rajasthan Royals             Rajasthan Royals
# 2009    Royal Challengers Bangalore  Royal Challengers Bangalore
# 2010                 Mumbai Indians          Chennai Super Kings
# ...

# %%
season.get_group(2016).sort_values('team1').drop_duplicates('team1').shape[0]
# Out:
# 8

# %%
season.mean()
# Out:
#            id  dl_applied  win_by_runs  win_by_wickets  umpire3
# season
# 2008     88.5    0.034483    12.155172        3.810345      NaN
# 2009    146.0    0.052632    13.403509        3.157895      NaN
# 2010    204.5    0.000000    16.266667        3.166667      NaN
# 2011    271.0    0.041096    15.041096        3.630137      NaN
# 2012    344.5    0.000000    12.972973        3.256757      NaN
# 2013    419.5    0.000000    16.328947        2.986842      NaN
# 2014    487.5    0.016667    10.733333        3.750000      NaN
# 2015    547.0    0.033898    14.406780        2.508475      NaN
# 2016    606.5    0.066667    11.266667        4.066667      NaN
# 2017     30.0    0.016949    13.355932        3.457627      NaN

# %%
season['win_by_runs'].mean().sort_values(ascending=False)
# Out:
# season
# 2013    16.328947
# 2010    16.266667
# 2011    15.041096
# 2015    14.406780
# 2009    13.403509
# 2017    13.355932
# 2012    12.972973
# 2008    12.155172
# 2016    11.266667
# 2014    10.733333
# Name: win_by_runs, dtype: float64

# %%
delivery=pd.read_csv('deliveries.csv')

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# ## to find the players with most runs in the IPL

# %%
runs=delivery.groupby('batsman')

# %%
runs['batsman','batsman_runs'].sum().sort_values('batsman_runs',ascending=False).head()
# Out:
# C:\Users\yashs\AppData\Local\Temp\ipykernel_24308\2769217818.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   runs['batsman','batsman_runs'].sum().sort_values('batsman_runs',ascending=False).head()
#            batsman_runs
# batsman
# SK Raina           4548
# V Kohli            4423
# RG Sharma          4207
# G Gambhir          4132
# DA Warner          4014

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# ## to find the players who hit max 2 runs

# %%
mask=delivery['batsman_runs']==2
new_delivery=delivery[mask]

# %%
six=new_delivery.groupby('batsman')['batsman_runs'].size()
six.sort_values(ascending=False).head()
# Out:
# batsman
# MS Dhoni     251
# G Gambhir    245
# SK Raina     242
# V Kohli      242
# DA Warner    207
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ## To find the team against which VK got the highest runs

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
mask=delivery[delivery['batsman']=='V Kohli']  ## to select the balls which VK played
#delivery[mask]
#VK=delivery[mask]

# %%
VK.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False)
# Out:
# bowling_team
# Chennai Super Kings        706
# Delhi Daredevils           661
# Kings XI Punjab            483
# Mumbai Indians             447
# Sunrisers Hyderabad        439
# Kolkata Knight Riders      391
# Deccan Chargers            306
# Gujarat Lions              283
# Rajasthan Royals           258
# Rising Pune Supergiants    188
# Pune Warriors              128
# Rising Pune Supergiant      83
# Kochi Tuskers Kerala        50
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ### function to find the top 3 teams aganst which a batsman scored the maximuum runs

# %%
 def runs_scored(batsman_name):
        batsman=delivery[delivery['batsman']==batsman_name]
        return batsman.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).head(3)

# %%
runs_scored('DA Warner')
# Out:
# bowling_team
# Kolkata Knight Riders          677
# Kings XI Punjab                668
# Royal Challengers Bangalore    569
# Name: batsman_runs, dtype: int64
